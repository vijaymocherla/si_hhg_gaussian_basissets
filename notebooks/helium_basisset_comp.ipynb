# %% [markdown]
# # Helium : HHG spectra of aQZ+(N,l,c) basis sets

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %% [markdown]
# # TD-CIS / aQZ+(k,k,0) k={3,4,5}

# %%
pulse = 'zs_1E14_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(5,5,0)':'he_aqz_550_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'he_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,80],ylim=[-12,27],legend_pos=[0.8,.2],figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(5,5,0)':'he_aqz_550_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'he_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,80],ylim=[-12,27],legend_pos=[0.8,.2],figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(5,5,0)':'he_aqz_550_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'he_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,100],ylim=[-12,27],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(5,5,0)':'he_aqz_550_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'he_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,120],ylim=[-12,27],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %% [markdown]
# # TD-CIS / aQZ+(k,k-1,1) k={4,5,6}

# %%
pulse = 'zs_1E14_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(6,5,1)':'he_aqz_651_cis_crt',
    'aQZ+(5,4,1)':'he_aqz_541_cis_crt', 
    'aQZ+(4,3,1)':'he_aqz_431_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,80],ylim=[-12,27],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(6,5,1)':'he_aqz_651_cis_crt',
    'aQZ+(5,4,1)':'he_aqz_541_cis_crt', 
    'aQZ+(4,3,1)':'he_aqz_431_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,80],ylim=[-12,27],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(6,5,1)':'he_aqz_651_cis_crt',
    'aQZ+(5,4,1)':'he_aqz_541_cis_crt', 
    'aQZ+(4,3,1)':'he_aqz_431_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,100],ylim=[-12,27],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(6,5,1)':'he_aqz_651_cis_crt',
    'aQZ+(5,4,1)':'he_aqz_541_cis_crt', 
    'aQZ+(4,3,1)':'he_aqz_431_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.1,120],ylim=[-12,27],legend_pos=[0.82,.26], figsize=(7.64,6.4))

# %% [markdown]
# # TD-CIS / aQZ+(N,4,0) N={1,2,3,4,5}

# %%
pulse = 'zs_1E14_54fs_800nm'
label = 'aqz_n40'
basissets = {
    'aQZ+(5,4,0)':'he_aqz_540_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,4,0)':'he_aqz_340_cis_crt',
    'aQZ+(2,4,0)':'he_aqz_240_cis_crt',
    'aQZ+(1,4,0)':'he_aqz_140_cis_crt',
}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.2,80],ylim=[-16,48],legend_pos=[0.8,.23], figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
label = 'aqz_n40'
basissets = {
    'aQZ+(5,4,0)':'he_aqz_540_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,4,0)':'he_aqz_340_cis_crt',
    'aQZ+(2,4,0)':'he_aqz_240_cis_crt',
    'aQZ+(1,4,0)':'he_aqz_140_cis_crt',
}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.2,80],ylim=[-16,48],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
label = 'aqz_n40'
basissets = {
    'aQZ+(5,4,0)':'he_aqz_540_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,4,0)':'he_aqz_340_cis_crt',
    'aQZ+(2,4,0)':'he_aqz_240_cis_crt',
    'aQZ+(1,4,0)':'he_aqz_140_cis_crt',
}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.2,100],ylim=[-16,48],legend_pos=[0.8,.2], figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
label = 'aqz_n40'
basissets = {
    'aQZ+(5,4,0)':'he_aqz_540_cis_crt',
    'aQZ+(4,4,0)':'he_aqz_440_cis_crt', 
    'aQZ+(3,4,0)':'he_aqz_340_cis_crt',
    'aQZ+(2,4,0)':'he_aqz_240_cis_crt',
    'aQZ+(1,4,0)':'he_aqz_140_cis_crt',
}
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-0.2,120],ylim=[-12,50],legend_pos=[0.8,.2], figsize=(7.64,6.4))
