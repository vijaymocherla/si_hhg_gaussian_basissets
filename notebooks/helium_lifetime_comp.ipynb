# %% [markdown]
# # TD-CIS / aQZ+(N,l,c) Lifetime Comparision

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %% [markdown]
# # aQZ+(3,3,0)

# %%
pulse = 'zs_1E14_54fs_800nm'
jobs = ['he_aqz_330_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(3,3,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-22,-3.5],xlim=[-0.20,60],plot_label='aqz_330_ltcomp',
                    colors=['blue'],subcolors=['orange'],legend_pos=[0.7,.75], figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
jobs = ['he_aqz_330_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(3,3,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-22,-3.5],xlim=[-0.20,80],plot_label='aqz_330_ltcomp',colors=['blue'],subcolors=['orange'],legend_pos=[0.7,.75], figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
jobs = ['he_aqz_330_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(3,3,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-18,-4],xlim=[-0.2,80],plot_label='aqz_330_ltcomp',colors=['blue'],subcolors=['orange'],legend_pos=[0.7,.75], figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
jobs = ['he_aqz_330_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(3,3,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-17.5,-2.5],xlim=[-0.2,80],plot_label='aqz_330_ltcomp',colors=['blue'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %% [markdown]
# # aQZ+(4,4,0)

# %%
pulse = 'zs_1E14_54fs_800nm'
jobs = ['he_aqz_440_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(4,4,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-20,-4],xlim=[-0.5,75],plot_label='aqz_440_ltcomp',colors=['green'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
jobs = ['he_aqz_440_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(4,4,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-20,-4],xlim=[-0.5,75],plot_label='aqz_440_ltcomp',colors=['green'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
jobs = ['he_aqz_440_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(4,4,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-19,-3],xlim=[-0.4,90], plot_label='aqz_440_ltcomp', 
                    colors=['green'],subcolors=['orange'],legend_pos=[0.75,.75], figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
jobs = ['he_aqz_440_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(4,4,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-18,-4],xlim=[-0.5,110],plot_label='aqz_440_ltcomp', colors=['green'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %% [markdown]
# # aQZ+(5,5,0)

# %%
pulse = 'zs_1E14_54fs_800nm'
jobs = ['he_aqz_550_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(5,5,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-21,-4],xlim=[-0.5,100],plot_label='aqz_550_ltcomp',colors=['red'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
jobs = ['he_aqz_550_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(5,5,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-20,-4],xlim=[-0.5,100],plot_label='aqz_550_ltcomp',colors=['red'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
jobs = ['he_aqz_550_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(5,5,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-20,-4],xlim=[-0.5,100],plot_label='aqz_550_ltcomp',colors=['red'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
jobs = ['he_aqz_550_cis_crt']*2
method = 'rk4'
labels = ['aQZ+(5,5,0)']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-18,-3.5],xlim=[-0.2,117],plot_label='aqz_550_ltcomp', colors=['red'],subcolors=['orange'],legend_pos=[0.7,.78], figsize=(7.64,6.4))
