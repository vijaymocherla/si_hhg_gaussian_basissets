# %% [markdown]
# # Helium : HHG spectra of aQZ basis sets

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %% [markdown]
# # TD-CIS / aQZ

# %%
pulse = 'zs_1E14_54fs_800nm'
label = 'axz'
basissets = {
    'a5Z':'he_a5z_cis_crt', 
    'aQZ':'he_aqz_cis_crt', 
    'aTZ':'he_atz_cis_crt', 
    'aDZ':'he_adz_cis_crt', 
    }
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-.1,60], ylim=[-18,36], use_lifetime=True, legend_pos=[.8,.65], figsize=(7.64,6.4))

# %%
pulse = 'zs_2E14_54fs_800nm'
label = 'axz'
basissets = {
    'a5Z':'he_a5z_cis_crt', 
    'aQZ':'he_aqz_cis_crt', 
    'aTZ':'he_atz_cis_crt', 
    'aDZ':'he_adz_cis_crt', 
    }
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-.1,80], ylim=[-18,36], use_lifetime=True, legend_pos=[.8, .5], figsize=(7.64,6.4))

# %%
pulse = 'zs_3E14_54fs_800nm'
label = 'axz'
basissets = {
    'a5Z':'he_a5z_cis_crt', 
    'aQZ':'he_aqz_cis_crt', 
    'aTZ':'he_atz_cis_crt', 
    'aDZ':'he_adz_cis_crt', 
    }
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-.1,100], ylim=[-18,36], use_lifetime=True, legend_pos=[.8,.56],figsize=(7.64,6.4))

# %%
pulse = 'zs_5E14_54fs_800nm'
label = 'axz'
basissets = {
    'a5Z':'he_a5z_cis_crt', 
    'aQZ':'he_aqz_cis_crt', 
    'aTZ':'he_atz_cis_crt', 
    'aDZ':'he_adz_cis_crt', 
    }
plot_hhg_basis_comp(basissets, pulse, label, xlim=[-.1,120], ylim=[-18,36], use_lifetime=True, legend_pos=[.8,.65],figsize=(7.64,6.4))
