# %% [markdown]
# # Helium : TD-CIS / aug-cc-pVQZ+(5,5,0)

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../../'),'scripts'))
from hhg_analysis import *

# %%
# setting the data directory
datadir = (os.path.join(os.path.realpath('../../'),'data/tdci/helium/he_aqz_550_cis_crt'))

# %% [markdown]
# ## $\text{I}_{0}$ = 1E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_1E14_54fs_800nm', xlim=[0,60], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 2E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_2E14_54fs_800nm', xlim=[0,60], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 3E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_3E14_54fs_800nm', xlim=[0,100], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 5E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_5E14_54fs_800nm', xlim=[0,120], method='rk4', savefig=False)
