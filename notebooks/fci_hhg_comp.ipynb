# %% [markdown]
# # TD-FCI / aug-cc-pVQZ

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %% [markdown]
# ## Helium

# %%
pulse = 'zs_1E14_54fs_800nm'
jobs = ['he_aqz_cis_crt', 'he_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-27,6],xlim=[-0.2,60],plot_label='fci', figsize=(7.64,6.4), legend_pos=[0.72, 0.7])

# %%
pulse = 'zs_2E14_54fs_800nm'
jobs = ['he_aqz_cis_crt', 'he_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-27,6],xlim=[-0.2,60],plot_label='fci', figsize=(7.64,6.4), legend_pos=[0.72, 0.7])

# %%
pulse = 'zs_3E14_54fs_800nm'
jobs = ['he_aqz_cis_crt', 'he_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-27,6],xlim=[-0.1,45],plot_label='fci',figsize=(7.64,6.4), legend_pos=[0.7, 0.7])

# %%
pulse = 'zs_5E14_54fs_800nm'
jobs = ['he_aqz_cis_crt', 'he_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, ylim=[-27,6],xlim=[-0.25,40],plot_label='fci',figsize=(7.64,6.4), legend_pos=[0.72, 0.7])

# %% [markdown]
# # Li+

# %%
pulse = 'zs_5E14_54fs_800nm'
jobs = ['li_plus_aqz_cis_crt', 'li_plus_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, atom_dir='li_plus',ylim=[-30,5],xlim=[-0.25,90],plot_label='fci', figsize=(7.64,6.4), legend_pos=[0.72, 0.7])

# %%
pulse = 'zs_7E14_54fs_800nm'
jobs = ['li_plus_aqz_cis_crt', 'li_plus_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, atom_dir='li_plus',ylim=[-30,5],xlim=[-0.5,105],plot_label='fci', figsize=(7.64,6.4), legend_pos=[0.72, 0.7])

# %%
pulse = 'zs_95E13_54fs_800nm'
jobs = ['li_plus_aqz_cis_crt', 'li_plus_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, atom_dir='li_plus',ylim=[-30,5],xlim=[-0.5,105],plot_label='fci',figsize=(7.80,6.5), legend_pos=[0.72, 0.71])

# %% [markdown]
# # H-

# %%
pulse = 'zs_45E11_54fs_800nm'
jobs = ['h_minus_aqz_cis_crt', 'h_minus_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, atom_dir='h_minus',ylim=[-22,8],xlim=[0.2,15],plot_label='fci',figsize=(7.80,6.5), legend_pos=[0.72, 0.7])

# %%
pulse = 'zs_95E11_54fs_800nm'
jobs = ['h_minus_aqz_cis_crt', 'h_minus_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, atom_dir='h_minus',ylim=[-22,8],xlim=[0.2,15],plot_label='fci',figsize=(7.64,6.4), legend_pos=[0.72, 0.7])

# %%
pulse = 'zs_15E12_54fs_800nm'
jobs = ['h_minus_aqz_cis_crt', 'h_minus_aqz_cisd_crt']
method = 'rk4'
labels = ['aQZ/CIS', 'aQZ/CISD']
plot_comp_lifetimes(jobs,pulse,labels, atom_dir='h_minus',ylim=[-22,8],xlim=[0.2,15],plot_label='fci',figsize=(7.64,6.4), legend_pos=[0.73, 0.7])
