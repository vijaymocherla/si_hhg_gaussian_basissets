# %% [markdown]
# # Helium : HHG spectra with different laser-pulse envelopes

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %%
datadir = os.path.join(os.path.realpath('../'),'data/tdci/helium/he_aqz_330_cis_crt')
basis = 'aQZ+(3,3,0)'
# 2E14
pulses_2e14 = ['zt_2E14_54fs_800nm', 'zs_2E14_54fs_800nm', 'zg_2E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_2e14, basis, xlim=[-0.2,80], ylim=[-22,-4])
# 3E14
pulses_3e14 = ['zt_3E14_54fs_800nm', 'zs_3E14_54fs_800nm', 'zg_3E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_3e14, basis, xlim=[-0.2,100], ylim=[-19,-4])
# 5E14
pulses_5e14 = ['zt_5E14_54fs_800nm', 'zs_5E14_54fs_800nm', 'zg_5E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_5e14, basis, xlim=[-0.2,120], ylim=[-19,-4])

# %%
datadir = os.path.join(os.path.realpath('../'),'data/tdci/helium/he_aqz_440_cis_crt')
basis = 'aQZ+(4,4,0)'
# 2E14
pulses_2e14 = ['zt_2E14_54fs_800nm', 'zs_2E14_54fs_800nm', 'zg_2E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_2e14, basis, xlim=[-0.2,80], ylim=[-20,-4])
# 3E14
pulses_3e14 = ['zt_3E14_54fs_800nm', 'zs_3E14_54fs_800nm', 'zg_3E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_3e14, basis, xlim=[-0.2,100],ylim=[-19,-4])
# 5E14
pulses_5e14 = ['zt_5E14_54fs_800nm', 'zs_5E14_54fs_800nm', 'zg_5E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_5e14, basis, xlim=[-0.2,120], ylim=[-19,-4])

# %%
datadir = os.path.join(os.path.realpath('../'),'data/tdci/helium/he_aqz_550_cis_crt')
basis = 'aQZ+(5,5,0)'
# 2E14
pulses_2e14 = ['zt_2E14_54fs_800nm', 'zs_2E14_54fs_800nm', 'zg_2E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_2e14, basis, xlim=[-.5,80],ylim=[-19,-4],)
# 3E14
pulses_3e14 = ['zt_3E14_54fs_800nm', 'zs_3E14_54fs_800nm', 'zg_3E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_3e14, basis, xlim=[-.5,100], ylim=[-19,-4])
# 5E14
pulses_5e14 = ['zt_5E14_54fs_800nm', 'zs_5E14_54fs_800nm', 'zg_5E14_54fs_800nm']
plot_hhg_pulse_comp(datadir, pulses_5e14, basis, xlim=[-.5,120], ylim=[-19,-4])
