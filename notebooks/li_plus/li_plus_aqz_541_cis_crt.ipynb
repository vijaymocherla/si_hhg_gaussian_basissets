# %% [markdown]
# # Li+ : TD-CIS / aQZ+(5,4,1)

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../../'),'scripts'))
from hhg_analysis import *

# %%
# setting the data directory
datadir = (os.path.join(os.path.realpath('../../'),'data/tdci/li_plus/li_plus_aqz_541_cis_crt'))

# %% [markdown]
# ## $\text{I}_{0}$ = 5E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_5E14_54fs_800nm', xlim=[0,120], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 7E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_7E14_54fs_800nm', xlim=[0,130], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 9.5E14 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_95E13_54fs_800nm', xlim=[0,130], method='rk4', savefig=False)
