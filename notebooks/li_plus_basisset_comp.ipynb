# %% [markdown]
# # Li+ : HHG spectra of aQZ+(N,l,c) basis sets

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %% [markdown]
# # TD-CIS / aQZ+(k,k,0) k={3,4}

# %%
pulse = 'zs_5E14_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(4,4,0)':'li_plus_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'li_plus_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='li_plus', xlim=[-0.5,130], ylim=[-12,15], savefig=True, figsize=(7.80,6.5), legend_pos=[0.8, 0.4], fontsize=20)

# %%
pulse = 'zs_7E14_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(4,4,0)':'li_plus_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'li_plus_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='li_plus',xlim=[-0.5,130],ylim=[-12,15], savefig=True, figsize=(7.80,6.5), legend_pos=[0.8, 0.4], fontsize=20)

# %%
pulse = 'zs_95E13_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(4,4,0)':'li_plus_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'li_plus_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='li_plus',xlim=[-0.5,130],ylim=[-12,15],savefig=True,figsize=(7.80,6.5), legend_pos=[0.8, 0.4], fontsize=20)

# %% [markdown]
# # TD-CIS / aQZ+(k,k-1,1) k={3,4,5}

# %%
pulse = 'zs_5E14_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(5,4,1)':'li_plus_aqz_541_cis_crt',
    'aQZ+(4,3,1)':'li_plus_aqz_431_cis_crt', 
}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='li_plus',xlim=[-0.5,120],ylim=[-18,15], savefig=True, figsize=(7.80,6.5), legend_pos=[0.8, 0.4], fontsize=20)

# %%
pulse = 'zs_7E14_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(5,4,1)':'li_plus_aqz_541_cis_crt',
    'aQZ+(4,3,1)':'li_plus_aqz_431_cis_crt', 
}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='li_plus',xlim=[-0.5,120],ylim=[-15,15], savefig=True, figsize=(7.80,6.5), legend_pos=[0.8, 0.4], fontsize=20)

# %%
pulse = 'zs_95E13_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(5,4,1)':'li_plus_aqz_541_cis_crt',
    'aQZ+(4,3,1)':'li_plus_aqz_431_cis_crt', 
}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='li_plus',xlim=[-0.5,130],ylim=[-10,15], savefig=True, figsize=(7.80,6.5), legend_pos=[0.8, 0.4], fontsize=20)
