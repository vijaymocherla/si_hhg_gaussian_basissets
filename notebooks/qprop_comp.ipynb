# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from qprop_analysis import *
from plotparams import *
from hhg_analysis import *

# %%
sae_path = '../data/qprop/helium_2E14/dat/' 
tdci_path = '../data/tdci/helium/he_aqz_440_cis_crt'
tdci_job = 'zs_2E14_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.72],
        xlim = [-.10,70], ylim = [-19,-3], figsize=[7.2, 6])

# %%
sae_path = '../data/qprop/helium_3E14/dat/' 
tdci_path = '../data/tdci/helium/he_aqz_440_cis_crt'
tdci_job = 'zs_3E14_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.7, 0.88], legend_pos=[0.7, 0.72],
        xlim = [-.10,90], ylim = [-19,-3], figsize=[7.2, 6])

# %%
sae_path = '../data/qprop/helium_5E14/dat/' 
tdci_path = '../data/tdci/helium/he_aqz_440_cis_crt'
tdci_job = 'zs_5E14_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.7],
        xlim = [-.20,110], ylim = [-17,-3], figsize=[7.2, 6])

# %% [markdown]
# # $\text{H}^{-}$

# %% [markdown]
# ## aQZ+(3,3,0)

# %%
sae_path = '../data/qprop/h_minus_45E11/dat/' 
tdci_path = '../data/tdci/h_minus/h_minus_aqz_330_cis_crt'
tdci_job = 'zs_45E11_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(3,3,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.7],
        xlim = [-.10,50], ylim = [-27,-0], figsize=[7.2, 6])

# %%
sae_path = '../data/qprop/h_minus_95E11/dat/' 
tdci_path = '../data/tdci/h_minus/h_minus_aqz_330_cis_crt'
tdci_job = 'zs_95E11_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(3,3,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.69],
        xlim = [-.10,60], ylim = [-25,-0], figsize=[7.2, 6])

# %%
sae_path = '../data/qprop/h_minus_15E12/dat/' 
tdci_path = '../data/tdci/h_minus/h_minus_aqz_330_cis_crt'
tdci_job = 'zs_15E12_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(3,3,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.7],
        xlim = [-.10,60], ylim = [-25,-0], figsize=[7.2, 6])

# %% [markdown]
# ## aQZ+(4,4,0)

# %%
sae_path = '../data/qprop/h_minus_45E11/dat/' 
tdci_path = '../data/tdci/h_minus/h_minus_aqz_440_cis_crt'
tdci_job = 'zs_45E11_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.7],
        xlim = [-.10,50], ylim = [-27,-0], figsize=[7.2, 6])

# %%
sae_path = '../data/qprop/h_minus_95E11/dat/' 
tdci_path = '../data/tdci/h_minus/h_minus_aqz_440_cis_crt'
tdci_job = 'zs_95E11_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.7],
        xlim = [-.10,60], ylim = [-27,-0], figsize=[7.2, 6])

# %%
sae_path = '../data/qprop/h_minus_15E12/dat/' 
tdci_path = '../data/tdci/h_minus/h_minus_aqz_440_cis_crt'
tdci_job = 'zs_15E12_54fs_800nm'
plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.7, 0.88], legend_pos=[0.71, 0.7],
        xlim = [-.10,60], ylim = [-27,-0], figsize=[7.2, 6])

# %%
sae_path = '../../../Desktop/qprophhg/src/li_plus/dat/' 
tdci_path = '../data/tdci/li_plus/li_plus_aqz_440_cis_crt'
tdci_job = 'zs_5E14_54fs_800nm'
data, fig, ax = plot_sae(sae_path, tdci_path, tdci_job, basis='aQZ+(4,4,0)', text_pos=[0.65, 0.88], legend_pos=[0.7, 0.73],
        xlim = [-.10,120], ylim = [-28,-2], figsize=[7.2, 6], return_data=True)

# %%
fig, ax = plt.subplots()
ax.plot(data['time_fs'], data['norm'])
ax1 = ax.twinx()
ax1.plot(data['time_fs'], data['dipole'])
