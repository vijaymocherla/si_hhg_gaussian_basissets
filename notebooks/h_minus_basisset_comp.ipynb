# %% [markdown]
# # H- : HHG spectra of aQZ+(N,l,c) basis sets

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../'),'scripts'))
from tdci_analysis import *

# %% [markdown]
# # TD-CIS / aQZ+(k,k,0) k={3,4}

# %%
pulse = 'zs_45E11_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(4,4,0)':'h_minus_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'h_minus_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='h_minus',xlim=[0.1,30],ylim=[-15,18], legend_pos=[.8,.6])

# %%
pulse = 'zs_95E11_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    'aQZ+(4,4,0)':'h_minus_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'h_minus_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='h_minus',xlim=[0.1,45],ylim=[-15,18], legend_pos=[.8,.6])

# %%
pulse = 'zs_15E12_54fs_800nm'
label = 'aqz_nn0'
basissets = {
    #'aQZ+(5,5,0)':'h_minus_aqz_550_cis_crt',
    'aQZ+(4,4,0)':'h_minus_aqz_440_cis_crt', 
    'aQZ+(3,3,0)':'h_minus_aqz_330_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='h_minus',xlim=[0.1,55],ylim=[-15,18],legend_pos=[.8,.6])

# %% [markdown]
# # TD-CIS / aQZ+(k,k-1,1) k={3,4,5}

# %%
pulse = 'zs_45E11_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(5,4,1)':'h_minus_aqz_541_cis_crt',
    'aQZ+(4,3,1)':'h_minus_aqz_431_cis_crt', 
    'aQZ+(3,2,1)':'h_minus_aqz_321_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='h_minus',xlim=[0.1,30],ylim=[-14,28],legend_pos=[.8,.65])

# %%
pulse = 'zs_95E11_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(5,4,1)':'h_minus_aqz_541_cis_crt',
    'aQZ+(4,3,1)':'h_minus_aqz_431_cis_crt', 
    'aQZ+(3,2,1)':'h_minus_aqz_321_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='h_minus',xlim=[0.1,30],ylim=[-14,28],legend_pos=[.8,.65])

# %%
pulse = 'zs_15E12_54fs_800nm'
label = 'aqz_nl1'
basissets = {
    'aQZ+(5,4,1)':'h_minus_aqz_541_cis_crt',
    'aQZ+(4,3,1)':'h_minus_aqz_431_cis_crt', 
    'aQZ+(3,2,1)':'h_minus_aqz_321_cis_crt'}
plot_hhg_basis_comp(basissets, pulse, label, atom_dir='h_minus',xlim=[0.1,30],ylim=[-14,28],legend_pos=[.8,.69])
