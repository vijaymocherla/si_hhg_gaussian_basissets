# %% [markdown]
# # H- : TD-CIS / aug-cc-pVQZ+(5,4,1)

# %%
import sys
import os
sys.path.append(os.path.join(os.path.realpath('../../'),'scripts'))
from hhg_analysis import *

# %%
# setting the data directory
datadir = (os.path.join(os.path.realpath('../../'),'data/tdci/h_minus/h_minus_aqz_541_cis_crt'))

# %% [markdown]
# ## $\text{I}_{0}$ = 45E11 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_45E11_54fs_800nm', xlim=[0,40], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 95E11 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_95E11_54fs_800nm', xlim=[0,50], method='rk4', savefig=False)

# %% [markdown]
# ## $\text{I}_{0}$ = 15E12 W/$\text{cm}^{2}$

# %%
plot_data(datadir, 'zs_15E12_54fs_800nm', xlim=[0,60], method='rk4', savefig=False)
